# %% [markdown]
# # How to crunch data from Elasticsearch with python
#
# - Elasticsearch docs: https://www.elastic.co/guide/en/elasticsearch/reference/current/index.html
# - Python Elasticsearch docs: https://elasticsearch-py.readthedocs.io/en/master/

# %%
import pandas as pd
import requests, json
from elasticsearch import Elasticsearch

pd.set_option('display.max_columns', 150)

# %% [markdown]
# ## Create the client and connect it to the cluster

# %%
host = 'http://35.198.135.86:9200'

es = Elasticsearch(host)

es.info()
# Out:
# {'name': '2a419d875914',
#  'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'a8qpewqwT2CP-JsWwCMbTg',
#  'version': {'number': '7.0.1',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': 'e4efcb5',
#   'build_date': '2019-04-29T12:56:03.145736Z',
#   'build_snapshot': False,
#   'lucene_version': '8.0.0',
#   'minimum_wire_compatibility_version': '6.7.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
index_0 = 'kibana_sample_data_flights'

index_1 = 'hh_vacancies'

# %% [markdown]
# ## Match query example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-query.html))

# %%
# All flights from Tokyo Haneda

query = {
    'query': {
        'match': {
            'Origin': 'Tokyo Haneda International Airport'
        }
    }
}

# %%
res = es.search(index=index_0, body=query)  # search in the 'Flights' index

sources = [hit['_source'] for hit in res['hits']['hits']]  # fetch only the body of each search hit

# %%
df = pd.DataFrame(sources).set_index('FlightNum')

df.head()
# Out:
#           DestCountry OriginWeather OriginCityName  AvgTicketPrice  \
# FlightNum
# M21BD4I            CN        Cloudy          Tokyo      969.189931
# KL2UKVD            CH        Cloudy          Tokyo      347.372958
# IR1FR9Z            JP         Sunny          Tokyo      227.668217
# J0I2OLF            PL         Clear          Tokyo      894.899226
# OP4CO7M            AT         Clear          Tokyo      505.499016
#
#            DistanceMiles  FlightDelay          DestWeather  \
# FlightNum
# M21BD4I      1754.412146         True                Clear
# KL2UKVD      5971.560559        False               Cloudy
# IR1FR9Z         0.000000         True                Clear
# J0I2OLF      5358.819441        False                 Rain
# OP4CO7M      5694.907068         True  Thunder & Lightning
#
#                                            Dest FlightDelayType OriginCountry  \
# FlightNum
# M21BD4I    Xi'an Xianyang International Airport       NAS Delay            JP
# KL2UKVD                          Zurich Airport        No Delay            JP
# IR1FR9Z      Tokyo Haneda International Airport   Carrier Delay            JP
# J0I2OLF                   Warsaw Chopin Airport        No Delay            JP
# OP4CO7M            Vienna International Airport   Carrier Delay            JP
#
#            dayOfWeek  DistanceKilometers            timestamp  \
# FlightNum
# M21BD4I            0         2823.452661  2019-11-04T20:17:26
# KL2UKVD            0         9610.295156  2019-11-04T22:34:35
# IR1FR9Z            0            0.000000  2019-11-04T14:16:01
# J0I2OLF            0         8624.183915  2019-11-04T12:43:08
# OP4CO7M            0         9165.064521  2019-11-04T07:31:56
#
#                                            DestLocation DestAirportID  \
# FlightNum
# M21BD4I       {'lat': '34.447102', 'lon': '108.751999'}           XIY
# KL2UKVD          {'lat': '47.464699', 'lon': '8.54917'}           ZRH
# IR1FR9Z       {'lat': '35.552299', 'lon': '139.779999'}           HND
# J0I2OLF    {'lat': '52.16569901', 'lon': '20.96710014'}           WAW
# OP4CO7M    {'lat': '48.11029816', 'lon': '16.56970024'}           VIE
#
#                     Carrier  Cancelled  FlightTimeMin  \
# FlightNum
# M21BD4I            JetBeats      False     261.172633
# KL2UKVD    Logstash Airways      False     600.643447
# IR1FR9Z            JetBeats      False     270.000000
# J0I2OLF    Logstash Airways      False     479.121329
# OP4CO7M    Logstash Airways      False     641.004301
#
#                                        Origin  \
# FlightNum
# M21BD4I    Tokyo Haneda International Airport
# KL2UKVD    Tokyo Haneda International Airport
# IR1FR9Z    Tokyo Haneda International Airport
# J0I2OLF    Tokyo Haneda International Airport
# OP4CO7M    Tokyo Haneda International Airport
#
#                                       OriginLocation DestRegion  \
# FlightNum
# M21BD4I    {'lat': '35.552299', 'lon': '139.779999'}      SE-BD
# KL2UKVD    {'lat': '35.552299', 'lon': '139.779999'}      CH-ZH
# IR1FR9Z    {'lat': '35.552299', 'lon': '139.779999'}      SE-BD
# J0I2OLF    {'lat': '35.552299', 'lon': '139.779999'}      PL-MZ
# OP4CO7M    {'lat': '35.552299', 'lon': '139.779999'}       AT-9
#
#           OriginAirportID OriginRegion DestCityName  FlightTimeHour  \
# FlightNum
# M21BD4I               HND        SE-BD        Xi'an        4.352877
# KL2UKVD               HND        SE-BD       Zurich       10.010724
# IR1FR9Z               HND        SE-BD        Tokyo        4.500000
# J0I2OLF               HND        SE-BD       Warsaw        7.985355
# OP4CO7M               HND        SE-BD       Vienna       10.683405
#
#            FlightDelayMin
# FlightNum
# M21BD4I               120
# KL2UKVD                 0
# IR1FR9Z               270
# J0I2OLF                 0
# OP4CO7M                30

# %% [markdown]
# ## Query string query example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-query-string-query.html))

# %%
# All the vacancies in Minsk or Kiev and with the word "Программист" in the name

query = {
    'query': {
        'query_string': {
            'query': 'address.city:(минск OR киев) AND name:(программист)'
        }
    }
}

# %%
res = es.search(index=index_1, body=query)  # search in the 'Vacancies' index

sources = [hit['_source'] for hit in res['hits']['hits']]

# %%
df = pd.DataFrame(sources).set_index('id')

df.head()
# Out:
#           premium                 name department  has_test  \
# id
# 34422421    False  Инженер-программист       None     False
# 34411360    False      Программист РНР       None     False
# 34411360    False      Программист РНР       None     False
# 34422421    False  Инженер-программист       None     False
# 34526548    False      Программист PHP       None     False
#
#           response_letter_required  \
# id
# 34422421                     False
# 34411360                     False
# 34411360                     False
# 34422421                     False
# 34526548                     False
#
#                                                        area  \
# id
# 34422421  {'id': '115', 'name': 'Киев', 'url': 'https://...
# 34411360  {'id': '115', 'name': 'Киев', 'url': 'https://...
# 34411360  {'id': '115', 'name': 'Киев', 'url': 'https://...
# 34422421  {'id': '115', 'name': 'Киев', 'url': 'https://...
# 34526548  {'id': '115', 'name': 'Киев', 'url': 'https://...
#
#                                                      salary  \
# id
# 34422421                                               None
# 34411360  {'from': None, 'to': 20000, 'currency': 'UAH',...
# 34411360  {'from': None, 'to': 20000, 'currency': 'UAH',...
# 34422421                                               None
# 34526548                                               None
#
#                                         type  \
# id
# 34422421  {'id': 'open', 'name': 'Открытая'}
# 34411360  {'id': 'open', 'name': 'Открытая'}
# 34411360  {'id': 'open', 'name': 'Открытая'}
# 34422421  {'id': 'open', 'name': 'Открытая'}
# 34526548  {'id': 'open', 'name': 'Открытая'}
#
#                                                     address response_url  \
# id
# 34422421  {'city': 'Киев', 'street': 'Бориспольская улиц...         None
# 34411360  {'city': 'Киев', 'street': 'улица Ушинского', ...         None
# 34411360  {'city': 'Киев', 'street': 'улица Ушинского', ...         None
# 34422421  {'city': 'Киев', 'street': 'Бориспольская улиц...         None
# 34526548  {'city': 'Киев', 'street': 'Сырецко-Печерская ...         None
#
#          sort_point_distance  \
# id
# 34422421                None
# 34411360                None
# 34411360                None
# 34422421                None
# 34526548                None
#
#                                                    employer  \
# id
# 34422421  {'id': '7045', 'name': 'Оптима-фарм, ЛТД', 'ur...
# 34411360  {'id': '3720430', 'name': 'СЕТРА', 'url': 'htt...
# 34411360  {'id': '3720430', 'name': 'СЕТРА', 'url': 'htt...
# 34422421  {'id': '7045', 'name': 'Оптима-фарм, ЛТД', 'ur...
# 34526548  {'id': '2788383', 'name': 'УКР КРЕДИТ ФИНАНС',...
#
#                       published_at                created_at  archived  \
# id
# 34422421  2019-11-05T17:19:45+0300  2019-11-05T17:19:45+0300     False
# 34411360  2019-11-05T12:10:33+0300  2019-11-05T12:10:33+0300     False
# 34411360  2019-11-05T12:10:33+0300  2019-11-05T12:10:33+0300     False
# 34422421  2019-11-05T17:19:45+0300  2019-11-05T17:19:45+0300     False
# 34526548  2019-11-12T11:34:12+0300  2019-11-12T11:34:12+0300     False
#
#                                         apply_alternate_url insider_interview  \
# id
# 34422421  https://hh.ru/applicant/vacancy_response?vacan...              None
# 34411360  https://hh.ru/applicant/vacancy_response?vacan...              None
# 34411360  https://hh.ru/applicant/vacancy_response?vacan...              None
# 34422421  https://hh.ru/applicant/vacancy_response?vacan...              None
# 34526548  https://hh.ru/applicant/vacancy_response?vacan...              None
#
#                                                       url  \
# id
# 34422421  https://api.hh.ru/vacancies/34422421?host=hh.ru
# 34411360  https://api.hh.ru/vacancies/34411360?host=hh.ru
# 34411360  https://api.hh.ru/vacancies/34411360?host=hh.ru
# 34422421  https://api.hh.ru/vacancies/34422421?host=hh.ru
# 34526548  https://api.hh.ru/vacancies/34526548?host=hh.ru
#
#                            alternate_url relations  \
# id
# 34422421  https://hh.ru/vacancy/34422421        []
# 34411360  https://hh.ru/vacancy/34411360        []
# 34411360  https://hh.ru/vacancy/34411360        []
# 34422421  https://hh.ru/vacancy/34422421        []
# 34526548  https://hh.ru/vacancy/34526548        []
#
#                                                     snippet  \
# id
# 34422421  {'requirement': 'Образование - полное высшее (...
# 34411360  {'requirement': 'Желаемый опыт работы PHP прог...
# 34411360  {'requirement': 'Желаемый опыт работы PHP прог...
# 34422421  {'requirement': 'Образование - полное высшее (...
# 34526548  {'requirement': 'Специалист уровня middle и вы...
#
#                                                    contacts
# id
# 34422421  {'name': 'Нестерова Вита', 'email': 'nesterova...
# 34411360                                               None
# 34411360                                               None
# 34422421  {'name': 'Нестерова Вита', 'email': 'nesterova...
# 34526548                                               None

# %% [markdown]
# ## Range query example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-range-query.html))

# %%
# All flights between 10 days ago from now on up to November, 13

query = {
    'query': {
        'range': {
            'timestamp': {
                # greater/less than (also "gte"/"lte" - greater/less than or equal available)
                # can be defined as ISO8601 timestamp or simply "now-NU", 
                # where N is an integer and U is the unit, e.g. "d" for days
                'gt': 'now-10d',
                'lte': '2019-11-13T06:00:00Z'
            }
        }
    }
}

# %%
res = es.search(index=index_0, body=query)  # search in the 'Flights' index

sources = [hit['_source'] for hit in res['hits']['hits']]

# %%
df = pd.DataFrame(sources).set_index('FlightNum')

df.head()
# Out:
#           DestCountry        OriginWeather OriginCityName  AvgTicketPrice  \
# FlightNum
# 01F7UGE            CN  Thunder & Lightning      Las Vegas      479.965664
# G03IV35            DE                Clear         Dublin      773.129178
# J75BL89            CN                Sunny        Norfolk      366.563175
# GBWN5IU            AR            Heavy Fog          Milan      968.406133
# IMVN7RN            AR                Sunny           Rome      275.100269
#
#            DistanceMiles  FlightDelay          DestWeather  \
# FlightNum
# 01F7UGE      6535.199878        False                Sunny
# G03IV35       677.305794        False  Thunder & Lightning
# J75BL89      7607.822454        False            Heavy Fog
# GBWN5IU      6946.527294        False               Cloudy
# IMVN7RN      6918.807715        False                 Rain
#
#                                                Dest FlightDelayType  \
# FlightNum
# 01F7UGE     Shanghai Hongqiao International Airport        No Delay
# G03IV35                   Frankfurt am Main Airport        No Delay
# J75BL89       Shanghai Pudong International Airport        No Delay
# GBWN5IU    Ministro Pistarini International Airport        No Delay
# IMVN7RN    Ministro Pistarini International Airport        No Delay
#
#           OriginCountry  dayOfWeek  DistanceKilometers            timestamp  \
# FlightNum
# 01F7UGE              US          3        10517.384712  2019-11-07T21:51:25
# G03IV35              IE          3         1090.018015  2019-11-07T20:45:42
# J75BL89              US          3        12243.603420  2019-11-07T12:52:28
# GBWN5IU              IT          3        11179.352022  2019-11-07T19:28:42
# IMVN7RN              IT          3        11134.741683  2019-11-07T10:54:35
#
#                                            DestLocation DestAirportID  \
# FlightNum
# 01F7UGE    {'lat': '31.19790077', 'lon': '121.3359985'}           SHA
# G03IV35         {'lat': '50.033333', 'lon': '8.570556'}           FRA
# J75BL89    {'lat': '31.14340019', 'lon': '121.8050003'}           PVG
# GBWN5IU          {'lat': '-34.8222', 'lon': '-58.5358'}           EZE
# IMVN7RN          {'lat': '-34.8222', 'lon': '-58.5358'}           EZE
#
#                     Carrier  Cancelled  FlightTimeMin  \
# FlightNum
# 01F7UGE            JetBeats      False     876.448726
# G03IV35              ES-Air      False      68.126126
# J75BL89     Kibana Airlines       True     720.211966
# GBWN5IU     Kibana Airlines      False     657.608942
# IMVN7RN    Logstash Airways      False     695.921355
#
#                                           Origin  \
# FlightNum
# 01F7UGE           McCarran International Airport
# G03IV35                           Dublin Airport
# J75BL89            Norfolk International Airport
# GBWN5IU           Malpensa International Airport
# IMVN7RN    Leonardo da Vinci___Fiumicino Airport
#
#                                           OriginLocation DestRegion  \
# FlightNum
# 01F7UGE    {'lat': '36.08010101', 'lon': '-115.1520004'}      SE-BD
# G03IV35    {'lat': '53.42129898', 'lon': '-6.270070076'}      DE-HE
# J75BL89    {'lat': '36.89459991', 'lon': '-76.20120239'}      SE-BD
# GBWN5IU             {'lat': '45.6306', 'lon': '8.72811'}       AR-B
# IMVN7RN       {'lat': '41.8002778', 'lon': '12.2388889'}       AR-B
#
#           OriginAirportID OriginRegion       DestCityName  FlightTimeHour  \
# FlightNum
# 01F7UGE               LAS        US-NV           Shanghai       14.607479
# G03IV35               DUB         IE-D  Frankfurt am Main        1.135435
# J75BL89               ORF        US-VA           Shanghai       12.003533
# GBWN5IU              MI12        IT-25       Buenos Aires       10.960149
# IMVN7RN              RM11        IT-62       Buenos Aires       11.598689
#
#            FlightDelayMin
# FlightNum
# 01F7UGE                 0
# G03IV35                 0
# J75BL89                 0
# GBWN5IU                 0
# IMVN7RN                 0

# %% [markdown]
# ## Bool query example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-bool-query.html))

# %%
# Search for all the flight sthat match several criteria: 
# the origin city is Ottawa, the flight was longer than 10 hours and it was flying within the last 15 days from now on

query = {
    'query': {
        'bool': {
            'must': [
                {
                    'match': {
                        'OriginCityName': 'Ottawa'
                    }
                },
                {
                    'query_string': {
                        'query': 'FlightTimeHour:>=10'
                    }
                },
                {
                    'range': {
                        'timestamp': {
                            'gt': 'now-15d',
                            'lte': 'now'
                        }
                    }
                }
            ]
        }
    }
}

# %%
res = es.search(index=index_0, body=query)

sources = [hit['_source'] for hit in res['hits']['hits']]

# %%
df = pd.DataFrame(sources).set_index('FlightNum')

df.head()
# Out:
#           DestCountry OriginWeather OriginCityName  AvgTicketPrice  \
# FlightNum
# NRE9J26            AT         Clear         Ottawa      374.899128
# 7ZTKP49            IT          Rain         Ottawa      893.927742
# 5SIPOMV            CN     Heavy Fog         Ottawa      576.047399
# 1X3WKIL            IT         Sunny         Ottawa      916.421259
# UYHN6BP            US          Rain         Ottawa      664.041076
#
#            DistanceMiles  FlightDelay DestWeather  \
# FlightNum
# NRE9J26      4106.857574        False        Rain
# 7ZTKP49      4036.535456        False      Cloudy
# 5SIPOMV      7057.750977        False      Cloudy
# 1X3WKIL      3865.611623        False   Heavy Fog
# UYHN6BP       376.858852         True       Clear
#
#                                               Dest FlightDelayType  \
# FlightNum
# NRE9J26               Vienna International Airport        No Delay
# 7ZTKP49                 Pisa International Airport        No Delay
# 5SIPOMV    Shanghai Hongqiao International Airport        No Delay
# 1X3WKIL                              Turin Airport        No Delay
# UYHN6BP         Philadelphia International Airport   Carrier Delay
#
#           OriginCountry  dayOfWeek  DistanceKilometers            timestamp  \
# FlightNum
# NRE9J26              CA          0         6609.346596  2019-11-04T06:23:10
# 7ZTKP49              CA          0         6496.174118  2019-11-04T13:10:09
# 5SIPOMV              CA          0        11358.349188  2019-11-04T15:56:09
# 1X3WKIL              CA          1         6221.098873  2019-11-05T02:40:32
# UYHN6BP              CA          1          606.495532  2019-11-05T14:04:19
#
#                                            DestLocation DestAirportID  \
# FlightNum
# NRE9J26    {'lat': '48.11029816', 'lon': '16.56970024'}           VIE
# 7ZTKP49          {'lat': '43.683899', 'lon': '10.3927'}          PI05
# 5SIPOMV    {'lat': '31.19790077', 'lon': '121.3359985'}           SHA
# 1X3WKIL          {'lat': '45.200802', 'lon': '7.64963'}          TO11
# UYHN6BP    {'lat': '39.87189865', 'lon': '-75.2410965'}           PHL
#
#                     Carrier  Cancelled  FlightTimeMin  \
# FlightNum
# NRE9J26    Logstash Airways      False     388.785094
# 7ZTKP49              ES-Air      False     309.341625
# 5SIPOMV     Kibana Airlines      False     811.310656
# 1X3WKIL     Kibana Airlines      False     327.426256
# UYHN6BP              ES-Air      False     136.920817
#
#                                                    Origin  \
# FlightNum
# NRE9J26    Ottawa Macdonald-Cartier International Airport
# 7ZTKP49    Ottawa Macdonald-Cartier International Airport
# 5SIPOMV    Ottawa Macdonald-Cartier International Airport
# 1X3WKIL    Ottawa Macdonald-Cartier International Airport
# UYHN6BP    Ottawa Macdonald-Cartier International Airport
#
#                                           OriginLocation DestRegion  \
# FlightNum
# NRE9J26    {'lat': '45.32249832', 'lon': '-75.66919708'}       AT-9
# 7ZTKP49    {'lat': '45.32249832', 'lon': '-75.66919708'}      IT-52
# 5SIPOMV    {'lat': '45.32249832', 'lon': '-75.66919708'}      SE-BD
# 1X3WKIL    {'lat': '45.32249832', 'lon': '-75.66919708'}      IT-21
# UYHN6BP    {'lat': '45.32249832', 'lon': '-75.66919708'}      US-PA
#
#           OriginAirportID OriginRegion  DestCityName  FlightTimeHour  \
# FlightNum
# NRE9J26               YOW        CA-ON        Vienna        6.479752
# 7ZTKP49               YOW        CA-ON          Pisa        5.155694
# 5SIPOMV               YOW        CA-ON      Shanghai       13.521844
# 1X3WKIL               YOW        CA-ON        Torino        5.457104
# UYHN6BP               YOW        CA-ON  Philadelphia        2.282014
#
#            FlightDelayMin
# FlightNum
# NRE9J26                 0
# 7ZTKP49                 0
# 5SIPOMV                 0
# 1X3WKIL                 0
# UYHN6BP               105

# %% [markdown]
# ## Date Histogram aggregation example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-datehistogram-aggregation.html))

# %%
# How many fligths per day where delayed by more than 2 hours

query = {
    'query': {
        'query_string': {
            'query': 'FlightDelayMin:>120'
        }
    },
    'aggs': {
        'per_day': {
            'date_histogram': {
                'field': 'timestamp',
                'interval': '1d'
            }
        }
    },
    'size': 0  # 'size' is 0 in this case because we don't really need the results themselves - only the time aggregation
}

# %%
res = es.search(index=index_0, body=query)

buckets = res['aggregations']['per_day']['buckets']

# %%
df = pd.DataFrame(buckets).set_index('key_as_string')

df.head(15)
# Out:
#                                     key  doc_count
# key_as_string
# 2019-11-04T00:00:00.000Z  1572825600000         48
# 2019-11-05T00:00:00.000Z  1572912000000         47
# 2019-11-06T00:00:00.000Z  1572998400000         62
# 2019-11-07T00:00:00.000Z  1573084800000         61
# 2019-11-08T00:00:00.000Z  1573171200000         57
# 2019-11-09T00:00:00.000Z  1573257600000         50
# 2019-11-10T00:00:00.000Z  1573344000000         41
# 2019-11-11T00:00:00.000Z  1573430400000         63
# 2019-11-12T00:00:00.000Z  1573516800000         60
# 2019-11-13T00:00:00.000Z  1573603200000         49
# 2019-11-14T00:00:00.000Z  1573689600000         50
# 2019-11-15T00:00:00.000Z  1573776000000         45
# 2019-11-16T00:00:00.000Z  1573862400000         54
# 2019-11-17T00:00:00.000Z  1573948800000         40
# 2019-11-18T00:00:00.000Z  1574035200000         51

# %% [markdown]
# ## Elastic saved object API ([doc](https://www.elastic.co/guide/en/kibana/master/saved-objects-api.html))

# %%
r = requests.get('http://35.198.135.86:5601' + '/api/saved_objects/_find?type=' + 'dashboard', verify=False)

r.json()
# Out:
# {'page': 1,
#  'per_page': 20,
#  'total': 2,
#  'saved_objects': [{'type': 'dashboard',
#    'id': '7adfa750-4c81-11e8-b3d7-01146121b73d',
#    'attributes': {'title': '[Flights] Global Flight Dashboard',
#     'hits': 0,
#     'description': 'Analyze mock flight data for ES-Air, Logstash Airways, Kibana Airlines and JetBeats',
#     'panelsJSON': '[{"panelIndex":"1","gridData":{"x":0,"y":0,"w":32,"h":7,"i":"1"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_0"},{"panelIndex":"3","gridData":{"x":17,"y":7,"w":23,"h":12,"i":"3"},"embeddableConfig":{"vis":{"colors":{"Average Ticket Price":"#0A50A1","Flight Count":"#82B5D8"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_1"},{"panelIndex":"4","gridData":{"x":0,"y":85,"w":48,"h":15,"i":"4"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_2"},{"panelIndex":"5","gridData":{"x":0,"y":7,"w":17,"h":12,"i":"5"},"embeddableConfig":{"vis":{"colors":{"ES-Air":"#447EBC","JetBeats":"#65C5DB","Kibana Airlines":"#BA43A9","Logstash Airways":"#E5AC0E"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_3"},{"panelIndex":"6","gridData":{"x":24,"y":33,"w":24,"h":14,"i":"6"},"embeddableConfig":{"vis":{"colors":{"Carrier Delay":"#5195CE","Late Aircraft Delay":"#1F78C1","NAS Delay":"#70DBED","No Delay":"#BADFF4","Security Delay":"#052B51","Weather Delay":"#6ED0E0"}}},"version":"6.3.0","panelRefName":"panel_4"},{"panelIndex":"7","gridData":{"x":24,"y":19,"w":24,"h":14,"i":"7"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_5"},{"panelIndex":"10","gridData":{"x":0,"y":35,"w":24,"h":12,"i":"10"},"embeddableConfig":{"vis":{"colors":{"Count":"#1F78C1"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_6"},{"panelIndex":"13","gridData":{"x":10,"y":19,"w":14,"h":8,"i":"13"},"embeddableConfig":{"vis":{"colors":{"Count":"#1F78C1"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_7"},{"panelIndex":"14","gridData":{"x":10,"y":27,"w":14,"h":8,"i":"14"},"embeddableConfig":{"vis":{"colors":{"Count":"#1F78C1"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_8"},{"panelIndex":"18","gridData":{"x":24,"y":70,"w":24,"h":15,"i":"18"},"embeddableConfig":{"mapCenter":[27.421687059550266,15.371002131141724],"mapZoom":1},"version":"6.3.0","panelRefName":"panel_9"},{"panelIndex":"21","gridData":{"x":0,"y":62,"w":48,"h":8,"i":"21"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_10"},{"panelIndex":"22","gridData":{"x":32,"y":0,"w":16,"h":7,"i":"22"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_11"},{"panelIndex":"23","gridData":{"x":0,"y":70,"w":24,"h":15,"i":"23"},"embeddableConfig":{"mapCenter":[42.19556096274418,9.536742995308601e-7],"mapZoom":1},"version":"6.3.0","panelRefName":"panel_12"},{"panelIndex":"25","gridData":{"x":0,"y":19,"w":10,"h":8,"i":"25"},"embeddableConfig":{"vis":{"defaultColors":{"0 - 50":"rgb(247,251,255)","100 - 150":"rgb(107,174,214)","150 - 200":"rgb(33,113,181)","200 - 250":"rgb(8,48,107)","50 - 100":"rgb(198,219,239)"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_13"},{"panelIndex":"27","gridData":{"x":0,"y":27,"w":10,"h":8,"i":"27"},"embeddableConfig":{"vis":{"defaultColors":{"0 - 50":"rgb(247,251,255)","100 - 150":"rgb(107,174,214)","150 - 200":"rgb(33,113,181)","200 - 250":"rgb(8,48,107)","50 - 100":"rgb(198,219,239)"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_14"},{"panelIndex":"28","gridData":{"x":0,"y":47,"w":24,"h":15,"i":"28"},"embeddableConfig":{"vis":{"defaultColors":{"0 - 11":"rgb(247,251,255)","11 - 22":"rgb(208,225,242)","22 - 33":"rgb(148,196,223)","33 - 44":"rgb(74,152,201)","44 - 55":"rgb(23,100,171)"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_15"},{"panelIndex":"29","gridData":{"x":40,"y":7,"w":8,"h":6,"i":"29"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_16"},{"panelIndex":"30","gridData":{"x":40,"y":13,"w":8,"h":6,"i":"30"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_17"},{"panelIndex":"31","gridData":{"x":24,"y":47,"w":24,"h":15,"i":"31"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_18"}]',
#     'optionsJSON': '{"hidePanelTitles":false,"useMargins":true}',
#     'version': 1,
#     'timeRestore': True,
#     'timeTo': 'now',
#     'timeFrom': 'now-24h',
#     'refreshInterval': {'display': '15 minutes',
#      'pause': False,
#      'section': 2,
#      'value': 900000},
#     'kibanaSavedObjectMeta': {'searchSourceJSON': '{"query":{"language":"kuery","query":""},"filter":[],"highlightAll":true,"version":true}'}},
#    'references': [{'name': 'panel_0',
#      'type': 'visualization',
#      'id': 'aeb212e0-4c84-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_1',
#      'type': 'visualization',
#      'id': 'c8fc3d30-4c87-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_2',
#      'type': 'search',
#      'id': '571aaf70-4c88-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_3',
#      'type': 'visualization',
#      'id': '8f4d0c00-4c86-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_4',
#      'type': 'visualization',
#      'id': 'f8290060-4c88-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_5',
#      'type': 'visualization',
#      'id': 'bcb63b50-4c89-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_6',
#      'type': 'visualization',
#      'id': '9886b410-4c8b-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_7',
#      'type': 'visualization',
#      'id': '76e3c090-4c8c-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_8',
#      'type': 'visualization',
#      'id': '707665a0-4c8c-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_9',
#      'type': 'visualization',
#      'id': '79e8ff60-4c8e-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_10',
#      'type': 'visualization',
#      'id': '293b5a30-4c8f-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_11',
#      'type': 'visualization',
#      'id': '129be430-4c93-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_12',
#      'type': 'visualization',
#      'id': '334084f0-52fd-11e8-a160-89cc2ad9e8e2'},
#     {'name': 'panel_13',
#      'type': 'visualization',
#      'id': 'f8283bf0-52fd-11e8-a160-89cc2ad9e8e2'},
#     {'name': 'panel_14',
#      'type': 'visualization',
#      'id': '08884800-52fe-11e8-a160-89cc2ad9e8e2'},
#     {'name': 'panel_15',
#      'type': 'visualization',
#      'id': 'e6944e50-52fe-11e8-a160-89cc2ad9e8e2'},
#     {'name': 'panel_16',
#      'type': 'visualization',
#      'id': '01c413e0-5395-11e8-99bf-1ba7b1bdaa61'},
#     {'name': 'panel_17',
#      'type': 'visualization',
#      'id': '2edf78b0-5395-11e8-99bf-1ba7b1bdaa61'},
#     {'name': 'panel_18',
#      'type': 'visualization',
#      'id': 'ed78a660-53a0-11e8-acbd-0be0ad9d822b'}],
#    'migrationVersion': {'dashboard': '7.0.0'},
#    'updated_at': '2019-11-15T20:08:28.399Z',
#    'version': 'WzI0LDFd'},
#   {'type': 'dashboard',
#    'id': 'edf84fe0-e1a0-11e7-b6d5-4dc382ef7f5b',
#    'attributes': {'title': '[Logs] Web Traffic',
#     'hits': 0,
#     'description': "Analyze mock web traffic log data for Elastic's website",
#     'panelsJSON': '[{"embeddableConfig":{"vis":{"colors":{"Avg. Bytes":"#6ED0E0","Unique Visitors":"#0A437C"},"legendOpen":false}},"gridData":{"x":27,"y":11,"w":21,"h":13,"i":"2"},"panelIndex":"2","version":"7.0.0-alpha1","panelRefName":"panel_0"},{"gridData":{"x":0,"y":49,"w":24,"h":18,"i":"4"},"panelIndex":"4","version":"7.0.0-alpha1","panelRefName":"panel_1"},{"embeddableConfig":{"vis":{"defaultColors":{"0 - 22":"rgb(247,251,255)","22 - 44":"rgb(208,225,242)","44 - 66":"rgb(148,196,223)","66 - 88":"rgb(74,152,201)","88 - 110":"rgb(23,100,171)"},"legendOpen":false}},"gridData":{"x":0,"y":36,"w":24,"h":13,"i":"7"},"panelIndex":"7","version":"6.3.0","panelRefName":"panel_2"},{"embeddableConfig":{"mapCenter":[36.8092847020594,-96.94335937500001],"vis":{"params":{"sort":{"columnIndex":null,"direction":null}}}},"gridData":{"x":27,"y":24,"w":21,"h":12,"i":"9"},"panelIndex":"9","version":"6.3.0","panelRefName":"panel_3"},{"embeddableConfig":{"vis":{"colors":{"0 - 500":"#BF1B00","1000 - 1500":"#7EB26D","500 - 1000":"#F2C96D"},"defaultColors":{"0 - 500":"rgb(165,0,38)","1000 - 1500":"rgb(0,104,55)","500 - 1000":"rgb(255,255,190)"},"legendOpen":false}},"gridData":{"x":10,"y":0,"w":9,"h":11,"i":"11"},"panelIndex":"11","title":"","version":"6.3.0","panelRefName":"panel_4"},{"gridData":{"x":0,"y":24,"w":27,"h":12,"i":"13"},"panelIndex":"13","version":"6.3.0","panelRefName":"panel_5"},{"gridData":{"x":24,"y":36,"w":24,"h":31,"i":"14"},"panelIndex":"14","version":"6.3.0","panelRefName":"panel_6"},{"gridData":{"x":0,"y":11,"w":27,"h":13,"i":"15"},"panelIndex":"15","version":"6.3.0","panelRefName":"panel_7"},{"gridData":{"x":19,"y":0,"w":15,"h":11,"i":"16"},"panelIndex":"16","title":"","version":"6.3.0","panelRefName":"panel_8"},{"embeddableConfig":{"vis":{"legendOpen":false}},"gridData":{"x":34,"y":0,"w":14,"h":11,"i":"17"},"panelIndex":"17","version":"6.3.0","panelRefName":"panel_9"},{"embeddableConfig":{},"gridData":{"x":0,"y":0,"w":10,"h":11,"i":"18"},"panelIndex":"18","title":"","version":"7.0.0-alpha1","panelRefName":"panel_10"}]',
#     'optionsJSON': '{"hidePanelTitles":false,"useMargins":true}',
#     'version': 1,
#     'timeRestore': True,
#     'timeTo': 'now',
#     'timeFrom': 'now-7d',
#     'refreshInterval': {'pause': False, 'value': 900000},
#     'kibanaSavedObjectMeta': {'searchSourceJSON': '{"query":{"language":"kuery","query":""},"filter":[],"highlightAll":true,"version":true}'}},
#    'references': [{'name': 'panel_0',
#      'type': 'visualization',
#      'id': 'e1d0f010-9ee7-11e7-8711-e7a007dcef99'},
#     {'name': 'panel_1',
#      'type': 'visualization',
#      'id': '06cf9c40-9ee8-11e7-8711-e7a007dcef99'},
#     {'name': 'panel_2',
#      'type': 'visualization',
#      'id': '935afa20-e0cd-11e7-9d07-1398ccfcefa3'},
#     {'name': 'panel_3',
#      'type': 'visualization',
#      'id': '4eb6e500-e1c7-11e7-b6d5-4dc382ef7f5b'},
#     {'name': 'panel_4',
#      'type': 'visualization',
#      'id': '69a34b00-9ee8-11e7-8711-e7a007dcef99'},
#     {'name': 'panel_5',
#      'type': 'visualization',
#      'id': '42b997f0-0c26-11e8-b0ec-3bb475f6b6ff'},
#     {'name': 'panel_6',
#      'type': 'visualization',
#      'id': '7cbd2350-2223-11e8-b802-5bcf64c2cfb4'},
#     {'name': 'panel_7',
#      'type': 'visualization',
#      'id': '314c6f60-2224-11e8-b802-5bcf64c2cfb4'},
#     {'name': 'panel_8',
#      'type': 'visualization',
#      'id': '24a3e970-4257-11e8-b3aa-73fdaf54bfc9'},
#     {'name': 'panel_9',
#      'type': 'visualization',
#      'id': '14e2e710-4258-11e8-b3aa-73fdaf54bfc9'},
#     {'name': 'panel_10',
#      'type': 'visualization',
#      'id': '47f2c680-a6e3-11e8-94b4-c30c0228351b'}],
#    'migrationVersion': {'dashboard': '7.0.0'},
#    'updated_at': '2019-11-15T20:08:30.392Z',
#    'version': 'WzQwLDFd'}]}

# %% [markdown]
# ## Elastic _cat API ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/cat.html))

# %%
r = requests.get(host + '/_cat/indices?format=json', verify=False)

r.json()
# Out:
# [{'health': 'green',
#   'status': 'open',
#   'index': '.kibana_task_manager',
#   'uuid': 'jGOO8WSAQ4qp9atSMzyCsQ',
#   'pri': '1',
#   'rep': '0',
#   'docs.count': '2',
#   'docs.deleted': '0',
#   'store.size': '30.4kb',
#   'pri.store.size': '30.4kb'},
#  {'health': 'green',
#   'status': 'open',
#   'index': 'kibana_sample_data_flights',
#   'uuid': '4aPdq4ygSRiuNh5JHmJ9oA',
#   'pri': '1',
#   'rep': '0',
#   'docs.count': '13059',
#   'docs.deleted': '0',
#   'store.size': '6.5mb',
#   'pri.store.size': '6.5mb'},
#  {'health': 'green',
#   'status': 'open',
#   'index': '.kibana_1',
#   'uuid': 'HxkjfN6oSlSdRgVW25gG4w',
#   'pri': '1',
#   'rep': '0',
#   'docs.count': '103',
#   'docs.deleted': '1',
#   'store.size': '182.5kb',
#   'pri.store.size': '182.5kb'},
#  {'health': 'green',
#   'status': 'open',
#   'index': 'kibana_sample_data_logs',
#   'uuid': 'vJOQ-DbeRFmJj6B2fCx5cg',
#   'pri': '1',
#   'rep': '0',
#   'docs.count': '14005',
#   'docs.deleted': '0',
#   'store.size': '11.5mb',
#   'pri.store.size': '11.5mb'},
#  {'health': 'yellow',
#   'status': 'open',
#   'index': 'hh_vacancies',
#   'uuid': 'xlA2G_iESWyq_X2A03NQ2A',
#   'pri': '1',
#   'rep': '1',
#   'docs.count': '10401',
#   'docs.deleted': '0',
#   'store.size': '18.6mb',
#   'pri.store.size': '18.6mb'}]

# %%
r = requests.get(host + '/_cluster/health', verify=False)

r.json()
# Out:
# {'cluster_name': 'docker-cluster',
#  'status': 'yellow',
#  'timed_out': False,
#  'number_of_nodes': 1,
#  'number_of_data_nodes': 1,
#  'active_primary_shards': 5,
#  'active_shards': 5,
#  'relocating_shards': 0,
#  'initializing_shards': 0,
#  'unassigned_shards': 1,
#  'delayed_unassigned_shards': 0,
#  'number_of_pending_tasks': 0,
#  'number_of_in_flight_fetch': 0,
#  'task_max_waiting_in_queue_millis': 0,
#  'active_shards_percent_as_number': 83.33333333333334}

# %%
r = requests.get(host + '/_nodes/stats', verify=False)

r.json()
# Out:
# {'_nodes': {'total': 1, 'successful': 1, 'failed': 0},
#  'cluster_name': 'docker-cluster',
#  'nodes': {'r4tce7bDTfqE5160qjWXow': {'timestamp': 1573890380931,
#    'name': '2a419d875914',
#    'transport_address': '172.18.0.2:9300',
#    'host': '172.18.0.2',
#    'ip': '172.18.0.2:9300',
#    'roles': ['master', 'data', 'ingest'],
#    'attributes': {'ml.machine_memory': '15760244736',
#     'xpack.installed': 'true',
#     'ml.max_open_jobs': '20'},
#    'indices': {'docs': {'count': 37570, 'deleted': 1},
#     'store': {'size_in_bytes': 38715043},
#     'indexing': {'index_total': 37522,
#      'index_time_in_millis': 12199,
#      'index_current': 0,
#      'index_failed': 1,
#      'delete_total': 0,
#      'delete_time_in_millis': 0,
#      'delete_current': 0,
#      'noop_update_total': 0,
#      'is_throttled': False,
#      'throttle_time_in_millis': 0},
#     'get': {'total': 4581,
#      'time_in_millis': 800,
#      'exists_total': 4235,
#      'exists_time_in_millis': 725,
#      'missing_total': 346,
#      'missing_time_in_millis': 75,
#      'current': 0},
#     'search': {'open_contexts': 0,
#      'query_total': 16685,
#      'query_time_in_millis': 1764,
#      'query_current': 0,
#      'fetch_total': 16675,
#      'fetch_time_in_millis': 1173,
#      'fetch_current': 0,
#      'scroll_total': 0,
#      'scroll_time_in_millis': 0,
#      'scroll_current': 0,
#      'suggest_total': 0,
#      'suggest_time_in_millis': 0,
#      'suggest_current': 0},
#     'merges': {'current': 0,
#      'current_docs': 0,
#      'current_size_in_bytes': 0,
#      'total': 2,
#      'total_time_in_millis': 3050,
#      'total_docs': 9491,
#      'total_size_in_bytes': 23808036,
#      'total_stopped_time_in_millis': 0,
#      'total_throttled_time_in_millis': 0,
#      'total_auto_throttle_in_bytes': 104857600},
#     'refresh': {'total': 93, 'total_time_in_millis': 6657, 'listeners': 0},
#     'flush': {'total': 10, 'periodic': 0, 'total_time_in_millis': 277},
#     'warmer': {'current': 0, 'total': 70, 'total_time_in_millis': 22},
#     'query_cache': {'memory_size_in_bytes': 0,
#      'total_count': 0,
#      'hit_count': 0,
#      'miss_count': 0,
#      'cache_size': 0,
#      'cache_count': 0,
#      'evictions': 0},
#     'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#     'completion': {'size_in_bytes': 0},
#     'segments': {'count': 25,
#      'memory_in_bytes': 300262,
#      'terms_memory_in_bytes': 227155,
#      'stored_fields_memory_in_bytes': 13608,
#      'term_vectors_memory_in_bytes': 0,
#      'norms_memory_in_bytes': 15872,
#      'points_memory_in_bytes': 2319,
#      'doc_values_memory_in_bytes': 41308,
#      'index_writer_memory_in_bytes': 0,
#      'version_map_memory_in_bytes': 0,
#      'fixed_bit_set_memory_in_bytes': 384,
#      'max_unsafe_auto_id_timestamp': -1,
#      'file_sizes': {}},
#     'translog': {'operations': 37514,
#      'size_in_bytes': 46275901,
#      'uncommitted_operations': 0,
#      'uncommitted_size_in_bytes': 275,
#      'earliest_last_modified_age': 0},
#     'request_cache': {'memory_size_in_bytes': 2527,
#      'evictions': 0,
#      'hit_count': 20,
#      'miss_count': 6},
#     'recovery': {'current_as_source': 0,
#      'current_as_target': 0,
#      'throttle_time_in_millis': 0}},
#    'os': {'timestamp': 1573890380945,
#     'cpu': {'percent': 0, 'load_average': {'1m': 0.0, '5m': 0.01, '15m': 0.0}},
#     'mem': {'total_in_bytes': 15760244736,
#      'free_in_bytes': 10239094784,
#      'used_in_bytes': 5521149952,
#      'free_percent': 65,
#      'used_percent': 35},
#     'swap': {'total_in_bytes': 0, 'free_in_bytes': 0, 'used_in_bytes': 0},
#     'cgroup': {'cpuacct': {'control_group': '/', 'usage_nanos': 498256199403},
#      'cpu': {'control_group': '/',
#       'cfs_period_micros': 100000,
#       'cfs_quota_micros': -1,
#       'stat': {'number_of_elapsed_periods': 0,
#        'number_of_times_throttled': 0,
#        'time_throttled_nanos': 0}},
#      'memory': {'control_group': '/',
#       'limit_in_bytes': '9223372036854771712',
#       'usage_in_bytes': '1621786624'}}},
#    'process': {'timestamp': 1573890380945,
#     'open_file_descriptors': 261,
#     'max_file_descriptors': 1048576,
#     'cpu': {'percent': 0, 'total_in_millis': 497400},
#     'mem': {'total_virtual_in_bytes': 4949442560}},
#    'jvm': {'timestamp': 1573890380946,
#     'uptime_in_millis': 45368714,
#     'mem': {'heap_used_in_bytes': 90639824,
#      'heap_used_percent': 8,
#      'heap_committed_in_bytes': 1038876672,
#      'heap_max_in_bytes': 1038876672,
#      'non_heap_used_in_bytes': 140234648,
#      'non_heap_committed_in_bytes': 153198592,
#      'pools': {'young': {'used_in_bytes': 816136,
#        'max_in_bytes': 279183360,
#        'peak_used_in_bytes': 279183360,
#        'peak_max_in_bytes': 279183360},
#       'survivor': {'used_in_bytes': 3011328,
#        'max_in_bytes': 34865152,
#        'peak_used_in_bytes': 34865152,
#        'peak_max_in_bytes': 34865152},
#       'old': {'used_in_bytes': 86812360,
#        'max_in_bytes': 724828160,
#        'peak_used_in_bytes': 86812360,
#        'peak_max_in_bytes': 724828160}}},
#     'threads': {'count': 56, 'peak_count': 58},
#     'gc': {'collectors': {'young': {'collection_count': 168,
#        'collection_time_in_millis': 1270},
#       'old': {'collection_count': 2, 'collection_time_in_millis': 167}}},
#     'buffer_pools': {'mapped': {'count': 30,
#       'used_in_bytes': 29837799,
#       'total_capacity_in_bytes': 29837799},
#      'direct': {'count': 109,
#       'used_in_bytes': 1938939,
#       'total_capacity_in_bytes': 1938938}},
#     'classes': {'current_loaded_count': 17611,
#      'total_loaded_count': 17611,
#      'total_unloaded_count': 0}},
#    'thread_pool': {'analyze': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'ccr': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'fetch_shard_started': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'fetch_shard_store': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'flush': {'threads': 1,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 2,
#      'completed': 20},
#     'force_merge': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'generic': {'threads': 6,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 6,
#      'completed': 102835},
#     'get': {'threads': 4,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 4,
#      'completed': 4570},
#     'listener': {'threads': 2,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 2,
#      'completed': 9},
#     'management': {'threads': 3,
#      'queue': 0,
#      'active': 1,
#      'rejected': 0,
#      'largest': 3,
#      'completed': 38367},
#     'ml_autodetect': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'ml_datafeed': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'ml_utility': {'threads': 1,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 1,
#      'completed': 1},
#     'refresh': {'threads': 2,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 2,
#      'completed': 213109},
#     'rollup_indexing': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'search': {'threads': 7,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 7,
#      'completed': 33362},
#     'search_throttled': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'security-token-key': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'snapshot': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'warmer': {'threads': 1,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 2,
#      'completed': 77},
#     'watcher': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'write': {'threads': 4,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 4,
#      'completed': 110}},
#    'fs': {'timestamp': 1573890380946,
#     'total': {'total_in_bytes': 10222829568,
#      'free_in_bytes': 6542905344,
#      'available_in_bytes': 6526128128},
#     'least_usage_estimate': {'path': '/usr/share/elasticsearch/data/nodes/0',
#      'total_in_bytes': 10222829568,
#      'available_in_bytes': 6526140416,
#      'used_disk_percent': 36.161114957560834},
#     'most_usage_estimate': {'path': '/usr/share/elasticsearch/data/nodes/0',
#      'total_in_bytes': 10222829568,
#      'available_in_bytes': 6526140416,
#      'used_disk_percent': 36.161114957560834},
#     'data': [{'path': '/usr/share/elasticsearch/data/nodes/0',
#       'mount': '/usr/share/elasticsearch/data (/dev/sda1)',
#       'type': 'ext4',
#       'total_in_bytes': 10222829568,
#       'free_in_bytes': 6542905344,
#       'available_in_bytes': 6526128128}],
#     'io_stats': {'devices': [{'device_name': 'sda1',
#        'operations': 80667,
#        'read_operations': 10219,
#        'write_operations': 70448,
#        'read_kilobytes': 44180,
#        'write_kilobytes': 978076}],
#      'total': {'operations': 80667,
#       'read_operations': 10219,
#       'write_operations': 70448,
#       'read_kilobytes': 44180,
#       'write_kilobytes': 978076}}},
#    'transport': {'server_open': 0,
#     'rx_count': 0,
#     'rx_size_in_bytes': 0,
#     'tx_count': 0,
#     'tx_size_in_bytes': 0},
#    'http': {'current_open': 12, 'total_opened': 102},
#    'breakers': {'request': {'limit_size_in_bytes': 623326003,
#      'limit_size': '594.4mb',
#      'estimated_size_in_bytes': 0,
#      'estimated_size': '0b',
#      'overhead': 1.0,
#      'tripped': 0},
#     'fielddata': {'limit_size_in_bytes': 415550668,
#      'limit_size': '396.2mb',
#      'estimated_size_in_bytes': 0,
#      'estimated_size': '0b',
#      'overhead': 1.03,
#      'tripped': 0},
#     'in_flight_requests': {'limit_size_in_bytes': 1038876672,
#      'limit_size': '990.7mb',
#      'estimated_size_in_bytes': 0,
#      'estimated_size': '0b',
#      'overhead': 2.0,
#      'tripped': 0},
#     'accounting': {'limit_size_in_bytes': 1038876672,
#      'limit_size': '990.7mb',
#      'estimated_size_in_bytes': 299974,
#      'estimated_size': '292.9kb',
#      'overhead': 1.0,
#      'tripped': 0},
#     'parent': {'limit_size_in_bytes': 986932838,
#      'limit_size': '941.2mb',
#      'estimated_size_in_bytes': 90639824,
#      'estimated_size': '86.4mb',
#      'overhead': 1.0,
#      'tripped': 0}},
#    'script': {'compilations': 2,
#     'cache_evictions': 0,
#     'compilation_limit_triggered': 0},
#    'discovery': {'cluster_state_queue': {'total': 0,
#      'pending': 0,
#      'committed': 0},
#     'published_cluster_states': {'full_states': 0,
#      'incompatible_diffs': 0,
#      'compatible_diffs': 0}},
#    'ingest': {'total': {'count': 0,
#      'time_in_millis': 0,
#      'current': 0,
#      'failed': 0},
#     'pipelines': {'xpack_monitoring_6': {'count': 0,
#       'time_in_millis': 0,
#       'current': 0,
#       'failed': 0,
#       'processors': [{'script': {'count': 0,
#          'time_in_millis': 0,
#          'current': 0,
#          'failed': 0}},
#        {'gsub': {'count': 0,
#          'time_in_millis': 0,
#          'current': 0,
#          'failed': 0}}]},
#      'xpack_monitoring_7': {'count': 0,
#       'time_in_millis': 0,
#       'current': 0,
#       'failed': 0,
#       'processors': []}}},
#    'adaptive_selection': {'r4tce7bDTfqE5160qjWXow': {'outgoing_searches': 0,
#      'avg_queue_size': 0,
#      'avg_service_time_ns': 125326,
#      'avg_response_time_ns': 317243,
#      'rank': '0.3'}}}}}
