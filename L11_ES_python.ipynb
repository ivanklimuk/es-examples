# %% [markdown]
# # L11: How to crunch data from Elasticsearch with python
#
# - Elasticsearch docs: https://www.elastic.co/guide/en/elasticsearch/reference/current/index.html
# - Python Elasticsearch docs: https://elasticsearch-py.readthedocs.io/en/master/

# %%
import pandas as pd
import requests, json
from elasticsearch import Elasticsearch

pd.set_option('display.max_columns', 150)

# %% [markdown]
# ## Create the client and connect it to the cluster

# %%
host = 'http://35.184.66.234:9200'

es = Elasticsearch(host)

es.info()
# Out:
# {'name': '8d6c4856853c',
#  'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'TtO4Ay54QEaJyMnLlFIlqA',
#  'version': {'number': '7.0.1',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': 'e4efcb5',
#   'build_date': '2019-04-29T12:56:03.145736Z',
#   'build_snapshot': False,
#   'lucene_version': '8.0.0',
#   'minimum_wire_compatibility_version': '6.7.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
index_0 = 'kibana_sample_data_flights'
index_1 = 'vacancies'

# %% [markdown]
# ## Match query example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-query.html))

# %%
# All flights from Tokyo Haneda

query = {
    'query': {
        'match': {
            'Origin': 'Tokyo Haneda International Airport'
        }
    }
}

# %%
res = es.search(index=index_0, body=query)  # search in the 'Flights' index

sources = [hit['_source'] for hit in res['hits']['hits']]  # fetch only the body of each search hit

# %%
df = pd.DataFrame(sources).set_index('FlightNum')

df.head()
# Out:
#            AvgTicketPrice  Cancelled           Carrier  \
# FlightNum
# M21BD4I        969.189931      False          JetBeats
# KL2UKVD        347.372958      False  Logstash Airways
# IR1FR9Z        227.668217      False          JetBeats
# J0I2OLF        894.899226      False  Logstash Airways
# OP4CO7M        505.499016      False  Logstash Airways
#
#                                            Dest DestAirportID DestCityName  \
# FlightNum
# M21BD4I    Xi'an Xianyang International Airport           XIY        Xi'an
# KL2UKVD                          Zurich Airport           ZRH       Zurich
# IR1FR9Z      Tokyo Haneda International Airport           HND        Tokyo
# J0I2OLF                   Warsaw Chopin Airport           WAW       Warsaw
# OP4CO7M            Vienna International Airport           VIE       Vienna
#
#           DestCountry                                  DestLocation  \
# FlightNum
# M21BD4I            CN     {'lat': '34.447102', 'lon': '108.751999'}
# KL2UKVD            CH        {'lat': '47.464699', 'lon': '8.54917'}
# IR1FR9Z            JP     {'lat': '35.552299', 'lon': '139.779999'}
# J0I2OLF            PL  {'lat': '52.16569901', 'lon': '20.96710014'}
# OP4CO7M            AT  {'lat': '48.11029816', 'lon': '16.56970024'}
#
#           DestRegion          DestWeather  DistanceKilometers  DistanceMiles  \
# FlightNum
# M21BD4I        SE-BD                Clear         2823.452661    1754.412146
# KL2UKVD        CH-ZH               Cloudy         9610.295156    5971.560559
# IR1FR9Z        SE-BD                Clear            0.000000       0.000000
# J0I2OLF        PL-MZ                 Rain         8624.183915    5358.819441
# OP4CO7M         AT-9  Thunder & Lightning         9165.064521    5694.907068
#
#            FlightDelay  FlightDelayMin FlightDelayType  FlightTimeHour  \
# FlightNum
# M21BD4I           True             120       NAS Delay        4.352877
# KL2UKVD          False               0        No Delay       10.010724
# IR1FR9Z           True             270   Carrier Delay        4.500000
# J0I2OLF          False               0        No Delay        7.985355
# OP4CO7M           True              30   Carrier Delay       10.683405
#
#            FlightTimeMin                              Origin OriginAirportID  \
# FlightNum
# M21BD4I       261.172633  Tokyo Haneda International Airport             HND
# KL2UKVD       600.643447  Tokyo Haneda International Airport             HND
# IR1FR9Z       270.000000  Tokyo Haneda International Airport             HND
# J0I2OLF       479.121329  Tokyo Haneda International Airport             HND
# OP4CO7M       641.004301  Tokyo Haneda International Airport             HND
#
#           OriginCityName OriginCountry  \
# FlightNum
# M21BD4I            Tokyo            JP
# KL2UKVD            Tokyo            JP
# IR1FR9Z            Tokyo            JP
# J0I2OLF            Tokyo            JP
# OP4CO7M            Tokyo            JP
#
#                                       OriginLocation OriginRegion  \
# FlightNum
# M21BD4I    {'lat': '35.552299', 'lon': '139.779999'}        SE-BD
# KL2UKVD    {'lat': '35.552299', 'lon': '139.779999'}        SE-BD
# IR1FR9Z    {'lat': '35.552299', 'lon': '139.779999'}        SE-BD
# J0I2OLF    {'lat': '35.552299', 'lon': '139.779999'}        SE-BD
# OP4CO7M    {'lat': '35.552299', 'lon': '139.779999'}        SE-BD
#
#           OriginWeather  dayOfWeek            timestamp
# FlightNum
# M21BD4I          Cloudy          0  2019-11-04T20:17:26
# KL2UKVD          Cloudy          0  2019-11-04T22:34:35
# IR1FR9Z           Sunny          0  2019-11-04T14:16:01
# J0I2OLF           Clear          0  2019-11-04T12:43:08
# OP4CO7M           Clear          0  2019-11-04T07:31:56

# %% [markdown]
# ## Query string query example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-query-string-query.html))

# %%
# All the vacancies in Minsk or Kiev and with the word "Программист" in the name

query = {
    'query': {
        'query_string': {
            'query': 'address.city:(минск OR киев) AND name:(программист)'
        }
    }
}

# %%
res = es.search(index=index_1, body=query)  # search in the 'Vacancies' index

sources = [hit['_source'] for hit in res['hits']['hits']]

# %%
df = pd.DataFrame(sources).set_index('id')

df.head()
# Out:
#                                                     address  \
# id
# 34094600  {'city': 'Киев', 'street': 'бульвар Академика ...
# 34094600  {'city': 'Киев', 'street': 'бульвар Академика ...
# 34422421  {'city': 'Киев', 'street': 'Бориспольская улиц...
# 34411360  {'city': 'Киев', 'street': 'улица Ушинского', ...
# 34422421  {'city': 'Киев', 'street': 'Бориспольская улиц...
#
#                            alternate_url  \
# id
# 34094600  https://hh.ru/vacancy/34094600
# 34094600  https://hh.ru/vacancy/34094600
# 34422421  https://hh.ru/vacancy/34422421
# 34411360  https://hh.ru/vacancy/34411360
# 34422421  https://hh.ru/vacancy/34422421
#
#                                         apply_alternate_url  archived  \
# id
# 34094600  https://hh.ru/applicant/vacancy_response?vacan...     False
# 34094600  https://hh.ru/applicant/vacancy_response?vacan...     False
# 34422421  https://hh.ru/applicant/vacancy_response?vacan...     False
# 34411360  https://hh.ru/applicant/vacancy_response?vacan...     False
# 34422421  https://hh.ru/applicant/vacancy_response?vacan...     False
#
#                                                        area  \
# id
# 34094600  {'id': '115', 'name': 'Киев', 'url': 'https://...
# 34094600  {'id': '115', 'name': 'Киев', 'url': 'https://...
# 34422421  {'id': '115', 'name': 'Киев', 'url': 'https://...
# 34411360  {'id': '115', 'name': 'Киев', 'url': 'https://...
# 34422421  {'id': '115', 'name': 'Киев', 'url': 'https://...
#
#                                                    contacts  \
# id
# 34094600                                               None
# 34094600                                               None
# 34422421  {'name': 'Нестерова Вита', 'email': 'nesterova...
# 34411360                                               None
# 34422421  {'name': 'Нестерова Вита', 'email': 'nesterova...
#
#                         created_at department  \
# id
# 34094600  2019-10-15T12:52:33+0300       None
# 34094600  2019-10-15T12:52:33+0300       None
# 34422421  2019-11-05T17:19:45+0300       None
# 34411360  2019-11-05T12:10:33+0300       None
# 34422421  2019-11-05T17:19:45+0300       None
#
#                                                    employer  has_test  \
# id
# 34094600  {'id': '33836', 'name': 'ВІДЖИ ТРЕЙД', 'url': ...     False
# 34094600  {'id': '33836', 'name': 'ВІДЖИ ТРЕЙД', 'url': ...     False
# 34422421  {'id': '7045', 'name': 'Оптима-фарм, ЛТД', 'ur...     False
# 34411360  {'id': '3720430', 'name': 'СЕТРА', 'url': 'htt...     False
# 34422421  {'id': '7045', 'name': 'Оптима-фарм, ЛТД', 'ur...     False
#
#          insider_interview                 name  premium  \
# id
# 34094600              None       Программист 1С    False
# 34094600              None       Программист 1С    False
# 34422421              None  Инженер-программист    False
# 34411360              None      Программист РНР    False
# 34422421              None  Инженер-программист    False
#
#                       published_at relations  response_letter_required  \
# id
# 34094600  2019-10-15T12:52:33+0300        []                     False
# 34094600  2019-10-15T12:52:33+0300        []                     False
# 34422421  2019-11-05T17:19:45+0300        []                     False
# 34411360  2019-11-05T12:10:33+0300        []                     False
# 34422421  2019-11-05T17:19:45+0300        []                     False
#
#          response_url                                             salary  \
# id
# 34094600         None                                               None
# 34094600         None                                               None
# 34422421         None                                               None
# 34411360         None  {'from': None, 'to': 20000, 'currency': 'UAH',...
# 34422421         None                                               None
#
#                                                     snippet  \
# id
# 34094600  {'requirement': 'Высшее образование. Опыт рабо...
# 34094600  {'requirement': 'Высшее образование. Опыт рабо...
# 34422421  {'requirement': 'Образование - полное высшее (...
# 34411360  {'requirement': 'Желаемый опыт работы PHP прог...
# 34422421  {'requirement': 'Образование - полное высшее (...
#
#          sort_point_distance   timestamp_ms  \
# id
# 34094600                None  1571133153000
# 34094600                None  1571133153000
# 34422421                None  1572963585000
# 34411360                None  1572945033000
# 34422421                None  1572963585000
#
#                                         type  \
# id
# 34094600  {'id': 'open', 'name': 'Открытая'}
# 34094600  {'id': 'open', 'name': 'Открытая'}
# 34422421  {'id': 'open', 'name': 'Открытая'}
# 34411360  {'id': 'open', 'name': 'Открытая'}
# 34422421  {'id': 'open', 'name': 'Открытая'}
#
#                                                       url
# id
# 34094600  https://api.hh.ru/vacancies/34094600?host=hh.ru
# 34094600  https://api.hh.ru/vacancies/34094600?host=hh.ru
# 34422421  https://api.hh.ru/vacancies/34422421?host=hh.ru
# 34411360  https://api.hh.ru/vacancies/34411360?host=hh.ru
# 34422421  https://api.hh.ru/vacancies/34422421?host=hh.ru

# %% [markdown]
# ## Range query example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-range-query.html))

# %%
# All flights between 10 days ago from now on up to November, 13

query = {
    'query': {
        'range': {
            'timestamp': {
                # greater/less than (also "gte"/"lte" - greater/less than or equal available)
                # can be defined as ISO8601 timestamp or simply "now-NU", 
                # where N is an integer and U is the unit, e.g. "d" for days
                'gt': 'now-10d',
                'lte': '2019-11-13T06:00:00Z'
            }
        }
    }
}

# %%
res = es.search(index=index_0, body=query)  # search in the 'Flights' index

sources = [hit['_source'] for hit in res['hits']['hits']]

# %%
df = pd.DataFrame(sources).set_index('FlightNum')

df.head()
# Out:
#            AvgTicketPrice  Cancelled           Carrier  \
# FlightNum
# X98CCZO        882.982662      False  Logstash Airways
# UFK2WIZ        190.636904      False  Logstash Airways
# EVARI8I        180.246816      False          JetBeats
# JQ2XXQ5        906.437948      False          JetBeats
# VT9O2KD        374.959276      False  Logstash Airways
#
#                                                      Dest DestAirportID  \
# FlightNum
# X98CCZO                         Venice Marco Polo Airport          VE05
# UFK2WIZ                         Venice Marco Polo Airport          VE05
# EVARI8I                                    Zurich Airport           ZRH
# JQ2XXQ5                           Helsinki Vantaa Airport           HEL
# VT9O2KD    Ottawa Macdonald-Cartier International Airport           YOW
#
#           DestCityName DestCountry  \
# FlightNum
# X98CCZO         Venice          IT
# UFK2WIZ         Venice          IT
# EVARI8I         Zurich          CH
# JQ2XXQ5       Helsinki          FI
# VT9O2KD         Ottawa          CA
#
#                                             DestLocation DestRegion  \
# FlightNum
# X98CCZO           {'lat': '45.505299', 'lon': '12.3519'}      IT-34
# UFK2WIZ           {'lat': '45.505299', 'lon': '12.3519'}      IT-34
# EVARI8I           {'lat': '47.464699', 'lon': '8.54917'}      CH-ZH
# JQ2XXQ5      {'lat': '60.31719971', 'lon': '24.9633007'}      FI-ES
# VT9O2KD    {'lat': '45.32249832', 'lon': '-75.66919708'}      CA-ON
#
#           DestWeather  DistanceKilometers  DistanceMiles  FlightDelay  \
# FlightNum
# X98CCZO         Sunny         8823.400140    5482.606665        False
# UFK2WIZ        Cloudy            0.000000       0.000000        False
# EVARI8I          Hail            0.000000       0.000000         True
# JQ2XXQ5          Rain         8551.767893    5313.822211        False
# VT9O2KD          Rain         6938.783926    4311.560441        False
#
#            FlightDelayMin FlightDelayType  FlightTimeHour  FlightTimeMin  \
# FlightNum
# X98CCZO                 0        No Delay        7.739825     464.389481
# UFK2WIZ                 0        No Delay        0.000000       0.000000
# EVARI8I               300  Security Delay        5.000000     300.000000
# JQ2XXQ5                 0        No Delay        8.384086     503.045170
# VT9O2KD                 0        No Delay        5.506971     330.418282
#
#                                               Origin OriginAirportID  \
# FlightNum
# X98CCZO              Cape Town International Airport             CPT
# UFK2WIZ                    Venice Marco Polo Airport            VE05
# EVARI8I                               Zurich Airport             ZRH
# JQ2XXQ5    Albuquerque International Sunport Airport             ABQ
# VT9O2KD                 Naples International Airport            NA01
#
#           OriginCityName OriginCountry  \
# FlightNum
# X98CCZO        Cape Town            ZA
# UFK2WIZ           Venice            IT
# EVARI8I           Zurich            CH
# JQ2XXQ5      Albuquerque            US
# VT9O2KD           Naples            IT
#
#                                           OriginLocation OriginRegion  \
# FlightNum
# X98CCZO    {'lat': '-33.96480179', 'lon': '18.60169983'}        SE-BD
# UFK2WIZ           {'lat': '45.505299', 'lon': '12.3519'}        IT-34
# EVARI8I           {'lat': '47.464699', 'lon': '8.54917'}        CH-ZH
# JQ2XXQ5       {'lat': '35.040199', 'lon': '-106.609001'}        US-NM
# VT9O2KD           {'lat': '40.886002', 'lon': '14.2908'}        IT-72
#
#           OriginWeather  dayOfWeek            timestamp
# FlightNum
# X98CCZO           Clear          0  2019-11-04T18:27:00
# UFK2WIZ            Rain          0  2019-11-04T17:11:14
# EVARI8I           Clear          0  2019-11-04T13:49:53
# JQ2XXQ5            Rain          0  2019-11-04T22:06:14
# VT9O2KD            Rain          0  2019-11-04T14:21:13

# %% [markdown]
# ## Bool query example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-bool-query.html))

# %%
# Search for all the flight sthat match several criteria: 
# the origin city is Ottawa, the flight was longer than 10 hours and it was flying within the last 15 days from now on

query = {
    'query': {
        'bool': {
            'must': [
                {
                    'match': {
                        'OriginCityName': 'Ottawa'
                    }
                },
                {
                    'query_string': {
                        'query': 'FlightTimeHour:>=10'
                    }
                },
                {
                    'range': {
                        'timestamp': {
                            'gt': 'now-15d',
                            'lte': 'now'
                        }
                    }
                }
            ]
        }
    }
}

# %%
res = es.search(index=index_0, body=query)

sources = [hit['_source'] for hit in res['hits']['hits']]

# %%
df = pd.DataFrame(sources).set_index('FlightNum')

df.head()
# Out:
#            AvgTicketPrice  Cancelled           Carrier  \
# FlightNum
# NRE9J26        374.899128      False  Logstash Airways
# 7ZTKP49        893.927742      False            ES-Air
# 5SIPOMV        576.047399      False   Kibana Airlines
# 1X3WKIL        916.421259      False   Kibana Airlines
# UYHN6BP        664.041076      False            ES-Air
#
#                                               Dest DestAirportID  \
# FlightNum
# NRE9J26               Vienna International Airport           VIE
# 7ZTKP49                 Pisa International Airport          PI05
# 5SIPOMV    Shanghai Hongqiao International Airport           SHA
# 1X3WKIL                              Turin Airport          TO11
# UYHN6BP         Philadelphia International Airport           PHL
#
#            DestCityName DestCountry  \
# FlightNum
# NRE9J26          Vienna          AT
# 7ZTKP49            Pisa          IT
# 5SIPOMV        Shanghai          CN
# 1X3WKIL          Torino          IT
# UYHN6BP    Philadelphia          US
#
#                                            DestLocation DestRegion  \
# FlightNum
# NRE9J26    {'lat': '48.11029816', 'lon': '16.56970024'}       AT-9
# 7ZTKP49          {'lat': '43.683899', 'lon': '10.3927'}      IT-52
# 5SIPOMV    {'lat': '31.19790077', 'lon': '121.3359985'}      SE-BD
# 1X3WKIL          {'lat': '45.200802', 'lon': '7.64963'}      IT-21
# UYHN6BP    {'lat': '39.87189865', 'lon': '-75.2410965'}      US-PA
#
#           DestWeather  DistanceKilometers  DistanceMiles  FlightDelay  \
# FlightNum
# NRE9J26          Rain         6609.346596    4106.857574        False
# 7ZTKP49        Cloudy         6496.174118    4036.535456        False
# 5SIPOMV        Cloudy        11358.349188    7057.750977        False
# 1X3WKIL     Heavy Fog         6221.098873    3865.611623        False
# UYHN6BP         Clear          606.495532     376.858852         True
#
#            FlightDelayMin FlightDelayType  FlightTimeHour  FlightTimeMin  \
# FlightNum
# NRE9J26                 0        No Delay        6.479752     388.785094
# 7ZTKP49                 0        No Delay        5.155694     309.341625
# 5SIPOMV                 0        No Delay       13.521844     811.310656
# 1X3WKIL                 0        No Delay        5.457104     327.426256
# UYHN6BP               105   Carrier Delay        2.282014     136.920817
#
#                                                    Origin OriginAirportID  \
# FlightNum
# NRE9J26    Ottawa Macdonald-Cartier International Airport             YOW
# 7ZTKP49    Ottawa Macdonald-Cartier International Airport             YOW
# 5SIPOMV    Ottawa Macdonald-Cartier International Airport             YOW
# 1X3WKIL    Ottawa Macdonald-Cartier International Airport             YOW
# UYHN6BP    Ottawa Macdonald-Cartier International Airport             YOW
#
#           OriginCityName OriginCountry  \
# FlightNum
# NRE9J26           Ottawa            CA
# 7ZTKP49           Ottawa            CA
# 5SIPOMV           Ottawa            CA
# 1X3WKIL           Ottawa            CA
# UYHN6BP           Ottawa            CA
#
#                                           OriginLocation OriginRegion  \
# FlightNum
# NRE9J26    {'lat': '45.32249832', 'lon': '-75.66919708'}        CA-ON
# 7ZTKP49    {'lat': '45.32249832', 'lon': '-75.66919708'}        CA-ON
# 5SIPOMV    {'lat': '45.32249832', 'lon': '-75.66919708'}        CA-ON
# 1X3WKIL    {'lat': '45.32249832', 'lon': '-75.66919708'}        CA-ON
# UYHN6BP    {'lat': '45.32249832', 'lon': '-75.66919708'}        CA-ON
#
#           OriginWeather  dayOfWeek            timestamp
# FlightNum
# NRE9J26           Clear          0  2019-11-04T06:23:10
# 7ZTKP49            Rain          0  2019-11-04T13:10:09
# 5SIPOMV       Heavy Fog          0  2019-11-04T15:56:09
# 1X3WKIL           Sunny          1  2019-11-05T02:40:32
# UYHN6BP            Rain          1  2019-11-05T14:04:19

# %% [markdown]
# ## Date Histogram aggregation example ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-datehistogram-aggregation.html))

# %%
# How many fligths per day where delayed by more than 2 hours

query = {
    'query': {
        'query_string': {
            'query': 'FlightDelayMin:>120'
        }
    },
    'aggs': {
        'per_day': {
            'date_histogram': {
                'field': 'timestamp',
                'interval': '1d'
            }
        }
    },
    'size': 0  # 'size' is 0 in this case because we don't really need the results themselves - only the time aggregation
}

# %%
res = es.search(index=index_0, body=query)

buckets = res['aggregations']['per_day']['buckets']

# %%
df = pd.DataFrame(buckets).set_index('key_as_string')

df.head(15)
# Out:
#                           doc_count            key
# key_as_string
# 2019-11-04T00:00:00.000Z         48  1572825600000
# 2019-11-05T00:00:00.000Z         47  1572912000000
# 2019-11-06T00:00:00.000Z         62  1572998400000
# 2019-11-07T00:00:00.000Z         61  1573084800000
# 2019-11-08T00:00:00.000Z         57  1573171200000
# 2019-11-09T00:00:00.000Z         50  1573257600000
# 2019-11-10T00:00:00.000Z         41  1573344000000
# 2019-11-11T00:00:00.000Z         63  1573430400000
# 2019-11-12T00:00:00.000Z         60  1573516800000
# 2019-11-13T00:00:00.000Z         49  1573603200000
# 2019-11-14T00:00:00.000Z         50  1573689600000
# 2019-11-15T00:00:00.000Z         45  1573776000000
# 2019-11-16T00:00:00.000Z         54  1573862400000
# 2019-11-17T00:00:00.000Z         40  1573948800000
# 2019-11-18T00:00:00.000Z         51  1574035200000

# %% [markdown]
# ## Elastic saved object API ([doc](https://www.elastic.co/guide/en/kibana/master/saved-objects-api.html))

# %%
r = requests.get('http://104.198.35.86:5601' + '/api/saved_objects/_find?type=' + 'dashboard', verify=False)
r.json()
# Out:
# {'page': 1,
#  'per_page': 20,
#  'total': 1,
#  'saved_objects': [{'type': 'dashboard',
#    'id': '7adfa750-4c81-11e8-b3d7-01146121b73d',
#    'attributes': {'title': '[Flights] Global Flight Dashboard',
#     'hits': 0,
#     'description': 'Analyze mock flight data for ES-Air, Logstash Airways, Kibana Airlines and JetBeats',
#     'panelsJSON': '[{"panelIndex":"1","gridData":{"x":0,"y":0,"w":32,"h":7,"i":"1"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_0"},{"panelIndex":"3","gridData":{"x":17,"y":7,"w":23,"h":12,"i":"3"},"embeddableConfig":{"vis":{"colors":{"Average Ticket Price":"#0A50A1","Flight Count":"#82B5D8"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_1"},{"panelIndex":"4","gridData":{"x":0,"y":85,"w":48,"h":15,"i":"4"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_2"},{"panelIndex":"5","gridData":{"x":0,"y":7,"w":17,"h":12,"i":"5"},"embeddableConfig":{"vis":{"colors":{"ES-Air":"#447EBC","JetBeats":"#65C5DB","Kibana Airlines":"#BA43A9","Logstash Airways":"#E5AC0E"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_3"},{"panelIndex":"6","gridData":{"x":24,"y":33,"w":24,"h":14,"i":"6"},"embeddableConfig":{"vis":{"colors":{"Carrier Delay":"#5195CE","Late Aircraft Delay":"#1F78C1","NAS Delay":"#70DBED","No Delay":"#BADFF4","Security Delay":"#052B51","Weather Delay":"#6ED0E0"}}},"version":"6.3.0","panelRefName":"panel_4"},{"panelIndex":"7","gridData":{"x":24,"y":19,"w":24,"h":14,"i":"7"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_5"},{"panelIndex":"10","gridData":{"x":0,"y":35,"w":24,"h":12,"i":"10"},"embeddableConfig":{"vis":{"colors":{"Count":"#1F78C1"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_6"},{"panelIndex":"13","gridData":{"x":10,"y":19,"w":14,"h":8,"i":"13"},"embeddableConfig":{"vis":{"colors":{"Count":"#1F78C1"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_7"},{"panelIndex":"14","gridData":{"x":10,"y":27,"w":14,"h":8,"i":"14"},"embeddableConfig":{"vis":{"colors":{"Count":"#1F78C1"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_8"},{"panelIndex":"18","gridData":{"x":24,"y":70,"w":24,"h":15,"i":"18"},"embeddableConfig":{"mapCenter":[27.421687059550266,15.371002131141724],"mapZoom":1},"version":"6.3.0","panelRefName":"panel_9"},{"panelIndex":"21","gridData":{"x":0,"y":62,"w":48,"h":8,"i":"21"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_10"},{"panelIndex":"22","gridData":{"x":32,"y":0,"w":16,"h":7,"i":"22"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_11"},{"panelIndex":"23","gridData":{"x":0,"y":70,"w":24,"h":15,"i":"23"},"embeddableConfig":{"mapCenter":[42.19556096274418,9.536742995308601e-7],"mapZoom":1},"version":"6.3.0","panelRefName":"panel_12"},{"panelIndex":"25","gridData":{"x":0,"y":19,"w":10,"h":8,"i":"25"},"embeddableConfig":{"vis":{"defaultColors":{"0 - 50":"rgb(247,251,255)","100 - 150":"rgb(107,174,214)","150 - 200":"rgb(33,113,181)","200 - 250":"rgb(8,48,107)","50 - 100":"rgb(198,219,239)"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_13"},{"panelIndex":"27","gridData":{"x":0,"y":27,"w":10,"h":8,"i":"27"},"embeddableConfig":{"vis":{"defaultColors":{"0 - 50":"rgb(247,251,255)","100 - 150":"rgb(107,174,214)","150 - 200":"rgb(33,113,181)","200 - 250":"rgb(8,48,107)","50 - 100":"rgb(198,219,239)"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_14"},{"panelIndex":"28","gridData":{"x":0,"y":47,"w":24,"h":15,"i":"28"},"embeddableConfig":{"vis":{"defaultColors":{"0 - 11":"rgb(247,251,255)","11 - 22":"rgb(208,225,242)","22 - 33":"rgb(148,196,223)","33 - 44":"rgb(74,152,201)","44 - 55":"rgb(23,100,171)"},"legendOpen":false}},"version":"6.3.0","panelRefName":"panel_15"},{"panelIndex":"29","gridData":{"x":40,"y":7,"w":8,"h":6,"i":"29"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_16"},{"panelIndex":"30","gridData":{"x":40,"y":13,"w":8,"h":6,"i":"30"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_17"},{"panelIndex":"31","gridData":{"x":24,"y":47,"w":24,"h":15,"i":"31"},"embeddableConfig":{},"version":"6.3.0","panelRefName":"panel_18"}]',
#     'optionsJSON': '{"hidePanelTitles":false,"useMargins":true}',
#     'version': 1,
#     'timeRestore': True,
#     'timeTo': 'now',
#     'timeFrom': 'now-24h',
#     'refreshInterval': {'display': '15 minutes',
#      'pause': False,
#      'section': 2,
#      'value': 900000},
#     'kibanaSavedObjectMeta': {'searchSourceJSON': '{"query":{"language":"kuery","query":""},"filter":[],"highlightAll":true,"version":true}'}},
#    'references': [{'name': 'panel_0',
#      'type': 'visualization',
#      'id': 'aeb212e0-4c84-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_1',
#      'type': 'visualization',
#      'id': 'c8fc3d30-4c87-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_2',
#      'type': 'search',
#      'id': '571aaf70-4c88-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_3',
#      'type': 'visualization',
#      'id': '8f4d0c00-4c86-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_4',
#      'type': 'visualization',
#      'id': 'f8290060-4c88-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_5',
#      'type': 'visualization',
#      'id': 'bcb63b50-4c89-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_6',
#      'type': 'visualization',
#      'id': '9886b410-4c8b-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_7',
#      'type': 'visualization',
#      'id': '76e3c090-4c8c-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_8',
#      'type': 'visualization',
#      'id': '707665a0-4c8c-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_9',
#      'type': 'visualization',
#      'id': '79e8ff60-4c8e-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_10',
#      'type': 'visualization',
#      'id': '293b5a30-4c8f-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_11',
#      'type': 'visualization',
#      'id': '129be430-4c93-11e8-b3d7-01146121b73d'},
#     {'name': 'panel_12',
#      'type': 'visualization',
#      'id': '334084f0-52fd-11e8-a160-89cc2ad9e8e2'},
#     {'name': 'panel_13',
#      'type': 'visualization',
#      'id': 'f8283bf0-52fd-11e8-a160-89cc2ad9e8e2'},
#     {'name': 'panel_14',
#      'type': 'visualization',
#      'id': '08884800-52fe-11e8-a160-89cc2ad9e8e2'},
#     {'name': 'panel_15',
#      'type': 'visualization',
#      'id': 'e6944e50-52fe-11e8-a160-89cc2ad9e8e2'},
#     {'name': 'panel_16',
#      'type': 'visualization',
#      'id': '01c413e0-5395-11e8-99bf-1ba7b1bdaa61'},
#     {'name': 'panel_17',
#      'type': 'visualization',
#      'id': '2edf78b0-5395-11e8-99bf-1ba7b1bdaa61'},
#     {'name': 'panel_18',
#      'type': 'visualization',
#      'id': 'ed78a660-53a0-11e8-acbd-0be0ad9d822b'}],
#    'migrationVersion': {'dashboard': '7.0.0'},
#    'updated_at': '2019-11-11T10:22:05.468Z',
#    'version': 'WzIzLDFd'}]}

# %% [markdown]
# ## Elastic _cat API ([doc](https://www.elastic.co/guide/en/elasticsearch/reference/current/cat.html))

# %%
r = requests.get(host + '/_cat/indices?format=json', verify=False)
r.json()
# Out:
# [{'health': 'green',
#   'status': 'open',
#   'index': '.kibana_task_manager',
#   'uuid': 'KyMD_3bxRryirGbkip9KWQ',
#   'pri': '1',
#   'rep': '0',
#   'docs.count': '2',
#   'docs.deleted': '0',
#   'store.size': '31kb',
#   'pri.store.size': '31kb'},
#  {'health': 'yellow',
#   'status': 'open',
#   'index': 'api',
#   'uuid': 's7S3jLdXSo2u8J4ENkT2-w',
#   'pri': '1',
#   'rep': '1',
#   'docs.count': '1',
#   'docs.deleted': '0',
#   'store.size': '2.6kb',
#   'pri.store.size': '2.6kb'},
#  {'health': 'green',
#   'status': 'open',
#   'index': 'kibana_sample_data_flights',
#   'uuid': '3wSM3M4qSTWy0B9LB37Ktg',
#   'pri': '1',
#   'rep': '0',
#   'docs.count': '13059',
#   'docs.deleted': '0',
#   'store.size': '6.4mb',
#   'pri.store.size': '6.4mb'},
#  {'health': 'yellow',
#   'status': 'open',
#   'index': 'vacancies',
#   'uuid': 'oxG2z2nxTXWo7-2anAZE8g',
#   'pri': '1',
#   'rep': '1',
#   'docs.count': '10436',
#   'docs.deleted': '0',
#   'store.size': '18.9mb',
#   'pri.store.size': '18.9mb'},
#  {'health': 'green',
#   'status': 'open',
#   'index': '.kibana_1',
#   'uuid': 'Z0cD8cscQeCxOAwRclavsw',
#   'pri': '1',
#   'rep': '0',
#   'docs.count': '71',
#   'docs.deleted': '10',
#   'store.size': '167.3kb',
#   'pri.store.size': '167.3kb'}]

# %%
r = requests.get(host + '/_cluster/health', verify=False)
r.json()
# Out:
# {'cluster_name': 'docker-cluster',
#  'status': 'yellow',
#  'timed_out': False,
#  'number_of_nodes': 1,
#  'number_of_data_nodes': 1,
#  'active_primary_shards': 5,
#  'active_shards': 5,
#  'relocating_shards': 0,
#  'initializing_shards': 0,
#  'unassigned_shards': 2,
#  'delayed_unassigned_shards': 0,
#  'number_of_pending_tasks': 0,
#  'number_of_in_flight_fetch': 0,
#  'task_max_waiting_in_queue_millis': 0,
#  'active_shards_percent_as_number': 71.42857142857143}

# %%
r = requests.get(host + '/_nodes/stats', verify=False)
r.json()
# Out:
# {'_nodes': {'total': 1, 'successful': 1, 'failed': 0},
#  'cluster_name': 'docker-cluster',
#  'nodes': {'f3PAEZmFRzaMUjVTBOrR-Q': {'timestamp': 1573651108999,
#    'name': '8d6c4856853c',
#    'transport_address': '172.18.0.2:9300',
#    'host': '172.18.0.2',
#    'ip': '172.18.0.2:9300',
#    'roles': ['master', 'data', 'ingest'],
#    'attributes': {'ml.machine_memory': '63321321472',
#     'xpack.installed': 'true',
#     'ml.max_open_jobs': '20'},
#    'indices': {'docs': {'count': 23569, 'deleted': 10},
#     'store': {'size_in_bytes': 26836917},
#     'indexing': {'index_total': 34098,
#      'index_time_in_millis': 7487,
#      'index_current': 0,
#      'index_failed': 1,
#      'delete_total': 1,
#      'delete_time_in_millis': 8,
#      'delete_current': 0,
#      'noop_update_total': 0,
#      'is_throttled': False,
#      'throttle_time_in_millis': 0},
#     'get': {'total': 18875,
#      'time_in_millis': 2421,
#      'exists_total': 18816,
#      'exists_time_in_millis': 2400,
#      'missing_total': 59,
#      'missing_time_in_millis': 21,
#      'current': 0},
#     'search': {'open_contexts': 0,
#      'query_total': 68663,
#      'query_time_in_millis': 6362,
#      'query_current': 0,
#      'fetch_total': 68616,
#      'fetch_time_in_millis': 23835,
#      'fetch_current': 0,
#      'scroll_total': 0,
#      'scroll_time_in_millis': 0,
#      'scroll_current': 0,
#      'suggest_total': 0,
#      'suggest_time_in_millis': 0,
#      'suggest_current': 0},
#     'merges': {'current': 0,
#      'current_docs': 0,
#      'current_size_in_bytes': 0,
#      'total': 7,
#      'total_time_in_millis': 2834,
#      'total_docs': 17101,
#      'total_size_in_bytes': 43794928,
#      'total_stopped_time_in_millis': 0,
#      'total_throttled_time_in_millis': 0,
#      'total_auto_throttle_in_bytes': 146800640},
#     'refresh': {'total': 187, 'total_time_in_millis': 5435, 'listeners': 0},
#     'flush': {'total': 20, 'periodic': 0, 'total_time_in_millis': 616},
#     'warmer': {'current': 0, 'total': 112, 'total_time_in_millis': 51},
#     'query_cache': {'memory_size_in_bytes': 0,
#      'total_count': 0,
#      'hit_count': 0,
#      'miss_count': 0,
#      'cache_size': 0,
#      'cache_count': 0,
#      'evictions': 0},
#     'fielddata': {'memory_size_in_bytes': 13416, 'evictions': 0},
#     'completion': {'size_in_bytes': 0},
#     'segments': {'count': 18,
#      'memory_in_bytes': 239341,
#      'terms_memory_in_bytes': 183042,
#      'stored_fields_memory_in_bytes': 10120,
#      'term_vectors_memory_in_bytes': 0,
#      'norms_memory_in_bytes': 13824,
#      'points_memory_in_bytes': 1451,
#      'doc_values_memory_in_bytes': 30904,
#      'index_writer_memory_in_bytes': 0,
#      'version_map_memory_in_bytes': 0,
#      'fixed_bit_set_memory_in_bytes': 336,
#      'max_unsafe_auto_id_timestamp': -1,
#      'file_sizes': {}},
#     'translog': {'operations': 16,
#      'size_in_bytes': 74276,
#      'uncommitted_operations': 0,
#      'uncommitted_size_in_bytes': 275,
#      'earliest_last_modified_age': 0},
#     'request_cache': {'memory_size_in_bytes': 3034328,
#      'evictions': 0,
#      'hit_count': 118,
#      'miss_count': 709},
#     'recovery': {'current_as_source': 0,
#      'current_as_target': 0,
#      'throttle_time_in_millis': 0}},
#    'os': {'timestamp': 1573651109002,
#     'cpu': {'percent': 0,
#      'load_average': {'1m': 0.07, '5m': 0.06, '15m': 0.01}},
#     'mem': {'total_in_bytes': 63321321472,
#      'free_in_bytes': 56580538368,
#      'used_in_bytes': 6740783104,
#      'free_percent': 89,
#      'used_percent': 11},
#     'swap': {'total_in_bytes': 0, 'free_in_bytes': 0, 'used_in_bytes': 0},
#     'cgroup': {'cpuacct': {'control_group': '/', 'usage_nanos': 1564695601197},
#      'cpu': {'control_group': '/',
#       'cfs_period_micros': 100000,
#       'cfs_quota_micros': -1,
#       'stat': {'number_of_elapsed_periods': 0,
#        'number_of_times_throttled': 0,
#        'time_throttled_nanos': 0}},
#      'memory': {'control_group': '/',
#       'limit_in_bytes': '9223372036854771712',
#       'usage_in_bytes': '2207891456'}}},
#    'process': {'timestamp': 1573651109003,
#     'open_file_descriptors': 416,
#     'max_file_descriptors': 1048576,
#     'cpu': {'percent': 0, 'total_in_millis': 1563860},
#     'mem': {'total_virtual_in_bytes': 11510775808}},
#    'jvm': {'timestamp': 1573651109003,
#     'uptime_in_millis': 183821632,
#     'mem': {'heap_used_in_bytes': 322810712,
#      'heap_used_percent': 31,
#      'heap_committed_in_bytes': 1037959168,
#      'heap_max_in_bytes': 1037959168,
#      'non_heap_used_in_bytes': 181099792,
#      'non_heap_committed_in_bytes': 191389696,
#      'pools': {'young': {'used_in_bytes': 190432472,
#        'max_in_bytes': 286326784,
#        'peak_used_in_bytes': 286326784,
#        'peak_max_in_bytes': 286326784},
#       'survivor': {'used_in_bytes': 1274504,
#        'max_in_bytes': 35782656,
#        'peak_used_in_bytes': 35782656,
#        'peak_max_in_bytes': 35782656},
#       'old': {'used_in_bytes': 131103736,
#        'max_in_bytes': 715849728,
#        'peak_used_in_bytes': 131103736,
#        'peak_max_in_bytes': 715849728}}},
#     'threads': {'count': 130, 'peak_count': 134},
#     'gc': {'collectors': {'young': {'collection_count': 706,
#        'collection_time_in_millis': 1852},
#       'old': {'collection_count': 2, 'collection_time_in_millis': 76}}},
#     'buffer_pools': {'mapped': {'count': 26,
#       'used_in_bytes': 19097430,
#       'total_capacity_in_bytes': 19097430},
#      'direct': {'count': 2634,
#       'used_in_bytes': 43637275,
#       'total_capacity_in_bytes': 43637274}},
#     'classes': {'current_loaded_count': 18159,
#      'total_loaded_count': 18159,
#      'total_unloaded_count': 0}},
#    'thread_pool': {'analyze': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'ccr': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'fetch_shard_started': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'fetch_shard_store': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'flush': {'threads': 1,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 4,
#      'completed': 40},
#     'force_merge': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'generic': {'threads': 4,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 4,
#      'completed': 408829},
#     'get': {'threads': 16,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 16,
#      'completed': 18793},
#     'listener': {'threads': 8,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 8,
#      'completed': 46},
#     'management': {'threads': 4,
#      'queue': 0,
#      'active': 1,
#      'rejected': 0,
#      'largest': 4,
#      'completed': 141230},
#     'ml_autodetect': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'ml_datafeed': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'ml_utility': {'threads': 1,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 1,
#      'completed': 1},
#     'refresh': {'threads': 5,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 5,
#      'completed': 649137},
#     'rollup_indexing': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'search': {'threads': 25,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 25,
#      'completed': 137299},
#     'search_throttled': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'security-token-key': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'snapshot': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'warmer': {'threads': 1,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 5,
#      'completed': 336},
#     'watcher': {'threads': 0,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 0,
#      'completed': 0},
#     'write': {'threads': 16,
#      'queue': 0,
#      'active': 0,
#      'rejected': 0,
#      'largest': 16,
#      'completed': 265}},
#    'fs': {'timestamp': 1573651109004,
#     'total': {'total_in_bytes': 25832407040,
#      'free_in_bytes': 22134116352,
#      'available_in_bytes': 22117339136},
#     'least_usage_estimate': {'path': '/usr/share/elasticsearch/data/nodes/0',
#      'total_in_bytes': 25832407040,
#      'available_in_bytes': 22117343232,
#      'used_disk_percent': 14.381407827181718},
#     'most_usage_estimate': {'path': '/usr/share/elasticsearch/data/nodes/0',
#      'total_in_bytes': 25832407040,
#      'available_in_bytes': 22117343232,
#      'used_disk_percent': 14.381407827181718},
#     'data': [{'path': '/usr/share/elasticsearch/data/nodes/0',
#       'mount': '/usr/share/elasticsearch/data (/dev/root)',
#       'type': 'ext4',
#       'total_in_bytes': 25832407040,
#       'free_in_bytes': 22134116352,
#       'available_in_bytes': 22117339136}],
#     'io_stats': {'devices': [{'device_name': 'sda1',
#        'operations': 266262,
#        'read_operations': 165,
#        'write_operations': 266097,
#        'read_kilobytes': 2864,
#        'write_kilobytes': 3782816}],
#      'total': {'operations': 266262,
#       'read_operations': 165,
#       'write_operations': 266097,
#       'read_kilobytes': 2864,
#       'write_kilobytes': 3782816}}},
#    'transport': {'server_open': 0,
#     'rx_count': 0,
#     'rx_size_in_bytes': 0,
#     'tx_count': 0,
#     'tx_size_in_bytes': 0},
#    'http': {'current_open': 21, 'total_opened': 780},
#    'breakers': {'request': {'limit_size_in_bytes': 622775500,
#      'limit_size': '593.9mb',
#      'estimated_size_in_bytes': 0,
#      'estimated_size': '0b',
#      'overhead': 1.0,
#      'tripped': 0},
#     'fielddata': {'limit_size_in_bytes': 415183667,
#      'limit_size': '395.9mb',
#      'estimated_size_in_bytes': 13416,
#      'estimated_size': '13.1kb',
#      'overhead': 1.03,
#      'tripped': 0},
#     'in_flight_requests': {'limit_size_in_bytes': 1037959168,
#      'limit_size': '989.8mb',
#      'estimated_size_in_bytes': 0,
#      'estimated_size': '0b',
#      'overhead': 2.0,
#      'tripped': 0},
#     'accounting': {'limit_size_in_bytes': 1037959168,
#      'limit_size': '989.8mb',
#      'estimated_size_in_bytes': 238541,
#      'estimated_size': '232.9kb',
#      'overhead': 1.0,
#      'tripped': 0},
#     'parent': {'limit_size_in_bytes': 986061209,
#      'limit_size': '940.3mb',
#      'estimated_size_in_bytes': 322810712,
#      'estimated_size': '307.8mb',
#      'overhead': 1.0,
#      'tripped': 0}},
#    'script': {'compilations': 4,
#     'cache_evictions': 0,
#     'compilation_limit_triggered': 0},
#    'discovery': {'cluster_state_queue': {'total': 0,
#      'pending': 0,
#      'committed': 0},
#     'published_cluster_states': {'full_states': 0,
#      'incompatible_diffs': 0,
#      'compatible_diffs': 0}},
#    'ingest': {'total': {'count': 0,
#      'time_in_millis': 0,
#      'current': 0,
#      'failed': 0},
#     'pipelines': {'xpack_monitoring_6': {'count': 0,
#       'time_in_millis': 0,
#       'current': 0,
#       'failed': 0,
#       'processors': [{'script': {'count': 0,
#          'time_in_millis': 0,
#          'current': 0,
#          'failed': 0}},
#        {'gsub': {'count': 0,
#          'time_in_millis': 0,
#          'current': 0,
#          'failed': 0}}]},
#      'xpack_monitoring_7': {'count': 0,
#       'time_in_millis': 0,
#       'current': 0,
#       'failed': 0,
#       'processors': []}}},
#    'adaptive_selection': {'f3PAEZmFRzaMUjVTBOrR-Q': {'outgoing_searches': 0,
#      'avg_queue_size': 0,
#      'avg_service_time_ns': 602433,
#      'avg_response_time_ns': 1115166,
#      'rank': '1.1'}}}}}
